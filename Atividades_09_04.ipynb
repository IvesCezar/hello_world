# %% [markdown]
# <a href="https://colab.research.google.com/github/IvesCezar/hello_world/blob/main/Atividades_09_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exemplos

# %%
int_numero= 10
int_numero2= int(11)
print(int_numero, int_numero2)
# Out:
# 10 11

# %% [markdown]
# "string"

# %%
text_uno ="saldo da conta bancaria inicial"
text2 = str("\nsaldo indisponivel")
print (text_uno, text2)
# Out:
# saldo da conta bancaria inicial
# saldo indisponivel

# %% [markdown]
# "dados booleano ou bool"

# %%
verdadeiro = True
falso = False
print (verdadeiro)
print(falso)
# Out:
# True
# False

# %%
soma = 1+50
print ('soma:', soma)
subtraçao = 50 - 1
print('subtraçao:', subtraçao)
multiplicaçao = 49 * 50
print('multiplicaçao:', multiplicaçao)
divisao = 49 / 50
print('divisao:' , divisao)
potencializacao = 2450 ** 4
print('potencializacao:', potencializacao)
# Out:
# soma: 51
# subtraçao: 49
# multiplicaçao: 2450
# divisao: 0.98
# potencializacao: 36030006250000

# %% [markdown]
# Questao 1

# %%
nome = "João Silva"
idade = 25
profissao = "Desenvolvedor"
print("Seu nome é:", nome,)
print("Sua idade é:", idade, "anos")
print("Sua profissao é:", profissao)
# Out:
# Seu nome é: João Silva
# Sua idade é: 25 anos
# Sua profissao é: Desenvolvedor

# %% [markdown]
# Questao 2

# %%
produto = "Notebook"
marca = "Dell"
preço = 4500
print ("produto:", produto)
print("marca:", marca)
print(f"preço R$ {preço:.2f}")
# Out:
# produto: Notebook
# marca: Dell
# preço R$ 4500.00

# %% [markdown]
# Questao 3

# %%
Numero1 = 12
Numero2 = 6
Soma = Numero1 + Numero2
Subtraçao = Numero1 - Numero2
Multiplicaçao = Numero1 * Numero2
Divisao = int(Numero1 / Numero2)
print("Soma:", soma)
print("Subtração:", Subtraçao)
print("Multiplicação:", Multiplicaçao)
print("Divisão:", Divisao)
# Out:
# Soma: 18
# Subtração: 6
# Multiplicação: 72
# Divisão: 2

# %% [markdown]
# Questao 4

# %%
num1 = 7
num2 = 2
calculo1 = num1 + num2
calculo2 = num1 - num2
calculo3 = num1 * num2
calculo4 = num1 / num2
calculo5 = num1 ** num2
print("soma:", calculo1)
print("subtração:", calculo2)
print("Multiplicação:", calculo3)
print("Divisão:", calculo4)
print("potencialização:", calculo5)
# Out:
# soma: 9
# subtração: 5
# Multiplicação: 14
# Divisão: 3.5
# potencialização: 49

# %% [markdown]
# Questão 5

# %%
Num1 = 15
Num2 = 5
S = Num1 + Num2
Sub = Num1 - Num2
Mult = Num1 * Num2
Div = Num1 / Num2
Pot = Num1 ** Num2
print("Soma de 15 + 5 =", S)
print("Subtração de 15 - 5=", Sub)
print("Multiplicação:", Mult)
print("Divisão:", Div)
print("Potencialização:", Pot)
# Out:
# Soma de 15 + 5 = 20
# Subtração de 15 - 5= 10
# Multiplicação: 75
# Divisão: 3.0
# Potencialização: 759375

# %% [markdown]
# Questao 6

# %%
N = (8.5, 7.0, 9.2)
tupla1 = N
pessoa = {"ALUNO:" "Carlos" "IDADE:" "21 anos" "CURSO:" "Engenharia"}

materias = ["Matemática", "História", "Biologia"]
print(materias)
print(tupla1)
print(pessoa)
# Out:
# ['Matemática', 'História', 'Biologia']
# (8.5, 7.0, 9.2)
# {'ALUNO:CarlosIDADE:21 anosCURSO:Engenharia'}
